# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
url = 'https://24h.pchome.com.tw/'
para = {
        "main subject" :["3C", "周邊", "NB", "通訊", "數位", "家電", "日用", "生活", "運動戶外", "美妝", "衣鞋包錶", "食品"],
        "3C":"https://24h.pchome.com.tw/sign/3c.htm",
        "周邊":"https://24h.pchome.com.tw/sign/cp.htm",
        "NB":"https://24h.pchome.com.tw/sign/nb.htm", 
        "通訊":"https://24h.pchome.com.tw/sign/mobile.htm", 
        "數位":"https://24h.pchome.com.tw/sign/digi.htm", 
        "家電":"https://24h.pchome.com.tw/sign/ce.htm", 
        "日用":"https://24h.pchome.com.tw/sign/daily.htm", 
        "生活":"https://24h.pchome.com.tw/sign/life.htm", 
        "運動戶外":"https://24h.pchome.com.tw/sign/outdoor.htm", 
        "美妝":"https://24h.pchome.com.tw/sign/beauty.htm", 
        "衣鞋包錶":"https://24h.pchome.com.tw/sign/vogue.htm", 
        "食品":"https://24h.pchome.com.tw/sign/food.htm"
        }

url = para[para["main subject"][0]]

# %%
wd = webdriver.Chrome('chromedriver85')#,chrome_options=chrome_options)
wd.get(url)

# %%
htmltext = wd.page_source
wd.close()

htmltext
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml"><head><script type="text/javascript" async="" src="https://www.google-analytics.com/plugins/ua/ec.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script src="https://connect.facebook.net/signals/config/548626015621996?v=2.9.24&amp;r=stable" async=""></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script type="text/javascript" async="" src="https://www.googletagmanager.com/gtag/js?id=G-9CE1X6J1FG&amp;l=dataLayer&amp;cx=c"></script>\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<meta http-equiv="Content-Language" content="zh-tw">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="author" content="PChome線上購物">\n<meta name="copyright" content="網路家庭版權所有、轉載必究 ● Copyright PChome Online">\n<meta name="keywords" content="">\n<meta name="description" content="">\n<meta name="robots" content="NOODP">\n<me
# ...

# %%
with open('sourceCode_selenium.txt', 'w', encoding='utf8') as f:
    f.write(htmltext)

# %%
sourceCode = BeautifulSoup(htmltext,'html.parser')
sourceCode
# Out:
# <html xmlns="http://www.w3.org/1999/xhtml"><head><script async="" src="https://www.google-analytics.com/plugins/ua/ec.js" type="text/javascript"></script><script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script><script async="" src="https://connect.facebook.net/signals/config/548626015621996?v=2.9.24&amp;r=stable"></script><script async="" src="https://connect.facebook.net/en_US/fbevents.js"></script><script async="" src="https://www.googletagmanager.com/gtag/js?id=G-9CE1X6J1FG&amp;l=dataLayer&amp;cx=c" type="text/javascript"></script>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="zh-tw" http-equiv="Content-Language"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="PChome線上購物" name="author"/>
# <meta content="網路家庭版權所有、轉載必究 ● Copyright PChome Online" name="copyright"/>
# <meta content="" name="keywords"/>
# <meta content="" name="description"/>
# ...
